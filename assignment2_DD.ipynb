# %% [markdown]
# <a href="https://colab.research.google.com/github/DDanso98/assignment2-DD/blob/main/assignment2_DD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 2: Git and GitHub Version Control | Dominic Danso - September 7, 2026**

# %% [markdown]
# Task 2 - Google Colab Environment

# %%
#Configure Git Within Colab
# !git --version
# !git config --global user.email "ddanso98@gmail.com"
# !git config --global user.name "DDanso98"
# !git config --global init.defaultBranch main
# Out:
# git version 2.34.1

# %%
#Confirm Configuration
# !git config --global user.name
# !git config --global user.email
# Out:
# DDanso98
# ddanso98@gmail.com

# %%
#Initialize GitHub Token
from google.colab import userdata

token = userdata.get('GitHubToken')
username = "DDanso98"
repo = "assignment2-DD"

# %% [markdown]
# Task 3 - Repository Setup

# %%
#Clone GitHub Repository
# !git clone https://github.com/DDanso98/assignment2-DD.git
# %cd assignment2-DD
# !ls
# !git status
# Out:
# Cloning into 'assignment2-DD'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 4.66 KiB | 4.66 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/assignment2-DD
# assignment2_DD.ipynb  README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git remote set-url origin https://{username}:{token}@github.com/{username}/{repo}.git
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git branch -m main

# %%
# !git branch
# Out:
# * main

# %% [markdown]
# Task 4 - Notebook Creation

# %% [markdown]
# **Git and GitHub Assignment 2**
#
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %% [markdown]
# Task 5 - Version Control Commands

# %%
# !git add assignment2_DD.ipynb
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git remote set-url origin https://{username}:{token}@github.com/{username}/{repo}.git
# !git push origin main
# Out:
# Everything up-to-date

# %% [markdown]
# Task 6 - Branching and Updates

# %%
#Create New Branch
# !git checkout -b feature-branch
# Out:
# Switched to a new branch 'feature-branch'

# %%
#Define New Function
def divide_numbers(a, b):
  if b != 0:
      return a / b
  else:
      return "Cannot divide by zero"

print(divide_numbers(10, 2))
# Out:
# 5.0

# %%
#Commit & Push Changes
# !git add assignment2_DD.ipynb
# !git commit -m "Add division function"
# !git push --set-upstream origin feature-branch
# Out:
# On branch feature-branch
# nothing to commit, working tree clean
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (10/10), 4.66 KiB | 4.66 MiB/s, done.
# Total 10 (delta 1), reused 10 (delta 1), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# remote:
# remote: Create a pull request for 'feature-branch' on GitHub by visiting:
# remote:      https://github.com/DDanso98/assignment2-DD/pull/new/feature-branch
# remote:
# To https://github.com/DDanso98/assignment2-DD.git
#  * [new branch]      feature-branch -> feature-branch
# Branch 'feature-branch' set up to track remote branch 'feature-branch' from 'origin'.

# %% [markdown]
# Colab Notebook: https://colab.research.google.com/github/DDanso98/assignment2-DD/blob/main/assignment2_DD.ipynb
#
# GitHub Repository: https://github.com/DDanso98/assignment2-DD/blob/74692c446a4c9d056e79330a71a2c1cddd1f8032/assignment2_DD.ipynb
