# %% [markdown]
# <a href="https://colab.research.google.com/github/DDanso98/assignment2-DD/blob/main/Assignment_2_DDanso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 2: Git and GitHub Version Control | Dominic Danso - September 7, 2026**

# %% [markdown]
# Task 2 - Google Colab Environment

# %%
#Configure Git Within Colab
# !git --version
# !git config --global user.email "ddanso98@gmail.com"
# !git config --global user.name "DDanso98"
# !git config --global init.defaultBranch main
# Out:
# git version 2.34.1

# %%
#Confirm Configuration
# !git config --global user.name
# !git config --global user.email
# Out:
# DDanso98
# ddanso98@gmail.com

# %%
#Initialize GitHub Token
from google.colab import userdata

token = userdata.get('GitHubToken')
username = "DDanso98"
repo = "assignment2-DD"

# %%
#

# %% [markdown]
# Task 3 - Repository Setup

# %%
#Clone GitHub Repository
# !git clone https://github.com/DDanso98/assignment2-DD.git
# %cd assignment2-DD
# !ls
# !git status
# Out:
# Cloning into 'assignment2-DD'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/assignment2-DD
# README.md
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git remote set-url origin https://{username}:{token}@github.com/{username}/{repo}.git
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !git branch -m main

# %%
# !git branch
# Out:
# * main

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Task 4 - Notebook Creation

# %% [markdown]
# **Git and GitHub Assignment 2**
#
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b
print(multiply_numbers(3, 4))
# Out:
# 12

# %% [markdown]
# Task 5 - Version Control Commands

# %%
# !git add assignment_2_DDanso.ipynb
# !git commit -m "Add initial notebook with multiplication function"
# Out:
# fatal: pathspec 'assignment_2_DDanso.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git remote add origin https://github.com/DDanso98/assignment2-DD.git
# !git push origin main

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/Introduction to Artificial Intelligence/"

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Introduction to Artificial Intelligence/Assignment 2 - DDanso.ipynb" "/content/Assignment2-DD/Assignment_2_DDanso.ipynb"
